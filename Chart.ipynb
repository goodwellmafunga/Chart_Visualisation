# %% [markdown]
# <a href="https://colab.research.google.com/github/goodwellmafunga/Chart_Visualisation/blob/main/Chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Plotting the Gantt chart for the project phases

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime, timedelta

# Project phases and durations (in weeks)
phases = ['Design', 'Development', 'Testing', 'Implementation', 'Evaluation']
start_dates = [datetime(2024, 1, 1), datetime(2024, 2, 1), datetime(2024, 4, 1), datetime(2024, 5, 1), datetime(2024, 6, 1)]
durations = [4, 8, 4, 4, 4]  # Durations in weeks

# Calculate the end dates for each phase
end_dates = [start + timedelta(weeks=duration) for start, duration in zip(start_dates, durations)]

# Plotting the Gantt chart
fig, ax = plt.subplots(figsize=(10, 6))

for i, (phase, start, end) in enumerate(zip(phases, start_dates, end_dates)):
    ax.barh(phase, (end - start).days, left=start, color='skyblue', edgecolor='black')

# Formatting the x-axis to show dates
ax.xaxis_date()
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
plt.xticks(rotation=45)

# Adding labels and title
ax.set_xlabel('Timeline')
ax.set_ylabel('Project Phases')
ax.set_title('Gantt Chart for IoT-Based Smart Medicine Dispenser Project')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime, timedelta

# Project phases and durations (in weeks)
phases = ['Develop QNN and ML models', 'Evaluate Performance', 'Deploy Highest Accuracy Model', 'Generate Real-time Reports']
start_dates = [datetime(2024, 5, 1), datetime(2024, 6, 15), datetime(2024, 8, 1), datetime(2024, 10, 1)]
durations = [6, 6, 6, 8]  # Durations in weeks

# Calculate the end dates for each phase
end_dates = [start + timedelta(weeks=duration) for start, duration in zip(start_dates, durations)]

# Plotting the Gantt chart
fig, ax = plt.subplots(figsize=(10, 6))

for i, (phase, start, end) in enumerate(zip(phases, start_dates, end_dates)):
    ax.barh(phase, (end - start).days, left=start, color='skyblue', edgecolor='black')

# Formatting the x-axis to show dates
ax.xaxis_date()
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
plt.xticks(rotation=45)

# Adding labels and title
ax.set_xlabel('Timeline')
ax.set_ylabel('Project Phases')
ax.set_title('Gantt Chart: Real-time Fraud Detection System (May 2024 - Dec 2024)')

plt.tight_layout()
plt.show()
